# %% [markdown]
# # Compare data availability in ESGF and google cloud

# %%
import intake
import os
import json

col_url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
col = intake.open_esm_datastore(col_url)

# %%
esgf_dir = '../Processed_data/Data_availability/ESGF/'
files = [ f.name for f in os.scandir(esgf_dir) if f.name[-12:] != '_models.json']
experiments = [file[5:-5] for file in files]
print(experiments)
# Out:
# ['ssp126', 'abrupt-2xCO2', 'ssp370', 'piControl', 'hist-aer', 'piClim-histall', 'ssp585', 'abrupt-4xCO2', 'ssp245', 'piClim-4xCO2', 'ssp119', 'historical', '1pctCO2', 'abrupt-0p5xCO2', 'piClim-control', 'hist-GHG', 'hist-nat']

# %%
var_list = ['tas', 'rlut', 'rsut', 'rsdt']

for experiment in experiments:
#for experiment in [experiments[0]]:
# load file of available data in esgf:
    with open('../Processed_data/Data_availability/ESGF/esgf-'+experiment+'.json', 'r') as f:
        exp_dict = json.load(f)
    # narrow search in google cloud:
    col_exp = col.search(experiment_id = experiment, variable_id=var_list, table_id='Amon')
    
    data_dict = {}; missing_dict = {}
    #for model in ['GISS-E2-1-H']:
    for model in exp_dict:
        if len(exp_dict[model])>0:
            members = exp_dict[model]
            col_model = col_exp.search(source_id = model)

            missing_members = []; cloud_members = []
            if len(members) == 0:
                print(experiment, model)
            for member in members:
                col_member = col_model.search(member_id = member)
                unique_vars = col_member.df['variable_id'].unique()
                cloud_versions = col_member.df['version'].unique()
                latest_esgf_version = [int(version[1:]) for version in exp_dict[model][member]]; 

                if len(unique_vars) < len(var_list):
                    missing_vars = set(var_list) - set(unique_vars)
                    missing_members.append(member)
                    print('Missing data:', experiment, model, member, 'is missing the variables', missing_vars)
                else:
                    # check if latest version(s) exist in cloud:
                    version_check = set(latest_esgf_version).issubset(set(cloud_versions))
                    if version_check == True:
                        cloud_members.append(member)
                    else:
                        missing_members.append(member)
                        print('Warning: only older version exist in the cloud for ', experiment, model, member)
                    #print(model, member, latest_esgf_version, cloud_versions, version_check)

            if len(cloud_members)>0:
                data_dict[model] = cloud_members;
            if len(missing_members)>0:
                missing_dict[model] = missing_members

    # write dictionaries to files:
    with open('../Processed_data/Data_availability/GoogleCloud/cloud-'+experiment+'.json', 'w') as f:
         json.dump(data_dict, f, indent = 2)
    with open('../Processed_data/Data_availability/GoogleCloud/missing-'+experiment+'.json', 'w') as f:
         json.dump(missing_dict, f, indent = 2)
# Out:
# Missing data: ssp126 ACCESS-CM2 r4i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-CM2 r5i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r10i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r11i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r12i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r13i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r14i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r15i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r16i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r17i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r18i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r19i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r20i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r21i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r22i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r23i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r24i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r25i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r26i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r27i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r28i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r29i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r30i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r31i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r32i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r33i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r34i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r35i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r36i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r37i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r38i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r39i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r40i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r4i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r5i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r6i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r7i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r8i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 ACCESS-ESM1-5 r9i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 CAS-ESM2-0 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 CAS-ESM2-0 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 CMCC-ESM2 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r101i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r102i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r103i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r104i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r105i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r106i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r107i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r108i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r109i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r110i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r111i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r112i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r113i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r114i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r115i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r116i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r117i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r118i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r119i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r120i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r121i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r122i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r123i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r124i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r125i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r126i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r127i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r128i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r129i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r130i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r131i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r132i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r133i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r134i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r135i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r136i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r137i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r138i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r139i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r140i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r141i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r142i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r143i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r144i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r145i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r146i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r147i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r148i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r149i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 EC-Earth3 r150i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# /Users/hege-beatefredriksen/opt/anaconda3/envs/CMIP6analysis/lib/python3.8/site-packages/intake_esm/search.py:106: UserWarning: Query returned zero results.
#   warn(message)
# Missing data: ssp126 GISS-E2-1-G r101i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 GISS-E2-1-G r1i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 GISS-E2-1-G r2i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 GISS-E2-1-G r3i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 GISS-E2-1-G r4i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 GISS-E2-1-G r5i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 IPSL-CM5A2-INCA r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 KIOST-ESM r1i1p1f1 is missing the variables {'rlut'}
# Missing data: ssp126 MIROC-ES2L r10i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp126 MIROC-ES2L r4i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp126 MIROC-ES2L r5i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC-ES2L r6i1p1f2 is missing the variables {'rsdt'}
# Missing data: ssp126 MIROC-ES2L r7i1p1f2 is missing the variables {'rlut', 'rsut'}
# Missing data: ssp126 MIROC-ES2L r8i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC-ES2L r9i1p1f2 is missing the variables {'rlut'}
# Missing data: ssp126 MIROC6 r10i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r11i1p1f1 is missing the variables {'rsdt'}
# Missing data: ssp126 MIROC6 r12i1p1f1 is missing the variables {'rlut'}
# Missing data: ssp126 MIROC6 r13i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r14i1p1f1 is missing the variables {'rsdt'}
# Missing data: ssp126 MIROC6 r15i1p1f1 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r16i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r17i1p1f1 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r18i1p1f1 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r19i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r20i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp126 MIROC6 r21i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r22i1p1f1 is missing the variables {'rsdt'}
# Missing data: ssp126 MIROC6 r23i1p1f1 is missing the variables {'rsdt'}
# Missing data: ssp126 MIROC6 r24i1p1f1 is missing the variables {'rsut'}
# Missing data: ssp126 MIROC6 r25i1p1f1 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r26i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r27i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r28i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r29i1p1f1 is missing the variables {'rsdt'}
# Missing data: ssp126 MIROC6 r30i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r31i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp126 MIROC6 r32i1p1f1 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r33i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r34i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r35i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r36i1p1f1 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r37i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r38i1p1f1 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r39i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r40i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r41i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r42i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp126 MIROC6 r43i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r44i1p1f1 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r45i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r46i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp126 MIROC6 r47i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r48i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp126 MIROC6 r49i1p1f1 is missing the variables {'rsdt'}
# Missing data: ssp126 MIROC6 r4i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r50i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r5i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp126 MIROC6 r6i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r7i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r8i1p1f1 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp126 MIROC6 r9i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp126 MPI-ESM1-2-LR r11i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r12i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r13i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r14i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r15i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r16i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r17i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r18i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r19i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r20i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r21i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r22i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r23i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r24i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r25i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r26i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r27i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r28i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r29i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MPI-ESM1-2-LR r30i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp126 MRI-ESM2-0 r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MRI-ESM2-0 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MRI-ESM2-0 r4i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp126 MRI-ESM2-0 r5i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Warning: only older version exist in the cloud for  ssp126 UKESM1-0-LL r4i1p1f2
# Missing data: abrupt-2xCO2 GISS-E2-1-H r1i1p5f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: abrupt-2xCO2 GISS-E2-2-H r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: abrupt-2xCO2 TaiESM1 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-CM2 r4i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-CM2 r5i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r10i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-ESM1-5 r11i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r12i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r13i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r14i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r15i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r16i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r17i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r18i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r19i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-ESM1-5 r20i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r21i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r22i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r23i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r24i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r25i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r26i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r27i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r28i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r29i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-ESM1-5 r30i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r31i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r32i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r33i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r34i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r35i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r36i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r37i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r38i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r39i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-ESM1-5 r40i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 ACCESS-ESM1-5 r4i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-ESM1-5 r5i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-ESM1-5 r6i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-ESM1-5 r7i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-ESM1-5 r8i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 ACCESS-ESM1-5 r9i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 CAS-ESM2-0 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 CAS-ESM2-0 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 CMCC-ESM2 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r101i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r102i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r103i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r104i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r105i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r106i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r107i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r108i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r109i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r110i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r111i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r112i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r113i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r114i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r115i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r116i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r117i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r118i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r119i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r120i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r121i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r122i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r123i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r124i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r125i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r126i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r127i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r128i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r129i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r130i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r131i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r132i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r133i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r134i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r135i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r136i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r137i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r138i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r139i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r140i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r141i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r142i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r143i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r144i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r145i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r146i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r147i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r148i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r149i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3 r150i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 EC-Earth3-AerChem r4i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Warning: only older version exist in the cloud for  ssp370 FGOALS-g3 r4i1p1f1
# Missing data: ssp370 GISS-E2-1-G r10i1p5f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 GISS-E2-1-G r1i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 GISS-E2-1-G r2i1p5f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 GISS-E2-1-G r3i1p5f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 GISS-E2-1-G r4i1p5f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 GISS-E2-1-G r5i1p5f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 GISS-E2-1-G r6i1p5f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 GISS-E2-1-G r7i1p5f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 GISS-E2-1-G r8i1p5f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 GISS-E2-1-G r9i1p5f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 GISS-E2-1-H r1i1p3f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 IPSL-CM5A2-INCA r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 MIROC-ES2L r10i1p1f2 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp370 MIROC-ES2L r3i1p1f2 is missing the variables {'rsut'}
# Missing data: ssp370 MIROC-ES2L r4i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp370 MIROC-ES2L r5i1p1f2 is missing the variables {'rsut'}
# Missing data: ssp370 MIROC-ES2L r6i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp370 MIROC-ES2L r7i1p1f2 is missing the variables {'rlut', 'rsdt'}
# Missing data: ssp370 MIROC-ES2L r8i1p1f2 is missing the variables {'rlut'}
# Missing data: ssp370 MIROC-ES2L r9i1p1f2 is missing the variables {'rlut'}
# Missing data: ssp370 MPI-ESM1-2-LR r11i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r12i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r13i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r14i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r15i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r16i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r17i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r18i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r19i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r20i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r21i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r22i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r23i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r24i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r25i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r26i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r27i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r28i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r29i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp370 MPI-ESM1-2-LR r30i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: piControl CMCC-ESM2 r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: piControl EC-Earth3-CC r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: piControl GISS-E2-2-H r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: piControl ICON-ESM-LR r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: piControl IPSL-CM5A2-INCA r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: piControl MIROC-ES2H r1i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: piControl MIROC-ES2H r1i1p2f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: piControl MIROC-ES2H r1i1p3f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: piControl NorESM2-LM r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: hist-aer ACCESS-CM2 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer ACCESS-CM2 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer ACCESS-CM2 r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer ACCESS-ESM1-5 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer ACCESS-ESM1-5 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer ACCESS-ESM1-5 r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer CESM2 r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer FGOALS-g3 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer FGOALS-g3 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer FGOALS-g3 r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r1i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r1i1p3f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r2i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r2i1p3f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r3i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r3i1p3f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r4i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r4i1p3f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r5i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer GISS-E2-1-G r5i1p3f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer HadGEM3-GC31-LL r5i1p1f3 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer MIROC6 r10i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer MIROC6 r4i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer MIROC6 r5i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer MIROC6 r6i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer MIROC6 r7i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer MIROC6 r8i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer MIROC6 r9i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer MRI-ESM2-0 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer MRI-ESM2-0 r4i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer NorESM2-LM r1i1p1f1 is missing the variables {'tas'}
# Missing data: hist-aer NorESM2-LM r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-aer NorESM2-LM r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: piClim-histall EC-Earth3 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: piClim-histall NorESM2-LM r1i1p2f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: piClim-histall NorESM2-LM r2i1p2f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: piClim-histall NorESM2-LM r3i1p2f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 ACCESS-CM2 r4i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-CM2 r5i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r10i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r11i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r12i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r13i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r14i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r15i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r16i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r17i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r18i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r19i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r20i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r21i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r22i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r23i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r24i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r25i1p1f1 is missing the variables {'rsut', 'tas', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r26i1p1f1 is missing the variables {'rsut', 'tas', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r27i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r28i1p1f1 is missing the variables {'rsut', 'tas', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r29i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r2i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r30i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r31i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r32i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r33i1p1f1 is missing the variables {'rsut', 'tas', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r34i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r35i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r36i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r37i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r38i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r39i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r3i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r40i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 ACCESS-ESM1-5 r4i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r5i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r6i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r7i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r8i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 ACCESS-ESM1-5 r9i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 CAS-ESM2-0 r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 CAS-ESM2-0 r3i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 CMCC-ESM2 r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 EC-Earth3-CC r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 EC-Earth3-Veg r10i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 EC-Earth3-Veg r12i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 EC-Earth3-Veg r14i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 GISS-E2-1-G r1i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 GISS-E2-1-G r2i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 GISS-E2-1-G r3i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp585 GISS-E2-1-G r4i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 GISS-E2-1-G r5i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 GISS-E2-1-H r1i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 GISS-E2-1-H r2i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 GISS-E2-1-H r3i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 GISS-E2-1-H r4i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 GISS-E2-1-H r5i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 IPSL-CM6A-LR r33i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MIROC-ES2L r10i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 MIROC-ES2L r2i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 MIROC-ES2L r3i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 MIROC-ES2L r4i1p1f2 is missing the variables {'rsdt'}
# Missing data: ssp585 MIROC-ES2L r6i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 MIROC-ES2L r7i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 MIROC-ES2L r8i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 MIROC-ES2L r9i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp585 MPI-ESM1-2-LR r11i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r12i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r13i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r14i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r15i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r16i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r17i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r18i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r19i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r20i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r21i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r22i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r23i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r24i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r25i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r26i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r27i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r28i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r29i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp585 MPI-ESM1-2-LR r30i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: abrupt-4xCO2 EC-Earth3-CC r1i1p1f1 is missing the variables {'rsdt'}
# Missing data: abrupt-4xCO2 GISS-E2-2-H r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: abrupt-4xCO2 ICON-ESM-LR r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: abrupt-4xCO2 IPSL-CM5A2-INCA r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: abrupt-4xCO2 MIROC-ES2H r1i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: abrupt-4xCO2 MIROC-ES2H r1i1p2f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: abrupt-4xCO2 MIROC-ES2H r1i1p3f2 is missing the variables {'rsut', 'rsdt'}
# Missing data: abrupt-4xCO2 NorESM2-LM r1i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: ssp245 ACCESS-CM2 r4i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-CM2 r5i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r10i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r11i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r12i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r13i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r14i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r15i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r16i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r17i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r18i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r19i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r20i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r21i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r22i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r23i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r24i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r25i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r26i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r27i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r28i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r29i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r30i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r31i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r32i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r33i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r34i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r35i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r36i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r37i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r38i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r39i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r40i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 ACCESS-ESM1-5 r4i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r5i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r6i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r7i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r8i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 ACCESS-ESM1-5 r9i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: ssp245 CAS-ESM2-0 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 CAS-ESM2-0 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 CMCC-ESM2 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 EC-Earth3 r101i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 EC-Earth3 r102i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 EC-Earth3 r103i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 EC-Earth3 r104i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: ssp245 EC-Earth3 r105i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# ...
# Missing data: historical MRI-ESM2-0 r9i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: historical TaiESM1 r2i1p1f1 is missing the variables {'rsut', 'rsdt'}
# Missing data: historical UKESM1-0-LL r15i1p1f2 is missing the variables {'rsut', 'rsdt'}
# Warning: only older version exist in the cloud for  1pctCO2 CAS-ESM2-0 r1i1p1f1
# Warning: only older version exist in the cloud for  1pctCO2 EC-Earth3 r3i1p1f1
# Missing data: 1pctCO2 EC-Earth3-CC r1i1p1f1 is missing the variables {'rlut'}
# Missing data: 1pctCO2 EC-Earth3-Veg r1i1p1f1 is missing the variables {'rsut'}
# Missing data: 1pctCO2 GISS-E2-2-H r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: 1pctCO2 ICON-ESM-LR r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: 1pctCO2 IPSL-CM5A2-INCA r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: abrupt-0p5xCO2 CanESM5 r1i1p2f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: abrupt-0p5xCO2 TaiESM1 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Warning: only older version exist in the cloud for  piClim-control BCC-ESM1 r1i1p1f1
# Missing data: piClim-control EC-Earth3 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: piClim-control EC-Earth3-AerChem r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: piClim-control GISS-E2-1-G r1i1p3f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: piClim-control MPI-ESM-1-2-HAM r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: piClim-control TaiESM1 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG ACCESS-CM2 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG ACCESS-CM2 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG ACCESS-CM2 r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG ACCESS-ESM1-5 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG ACCESS-ESM1-5 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG ACCESS-ESM1-5 r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Warning: only older version exist in the cloud for  hist-GHG CNRM-CM6-1 r3i1p1f2
# Missing data: hist-GHG FGOALS-g3 r1i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG FGOALS-g3 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG FGOALS-g3 r3i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG GISS-E2-1-G r1i1p1f2 is missing the variables {'rsut'}
# Missing data: hist-GHG GISS-E2-1-G r2i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG GISS-E2-1-G r3i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG GISS-E2-1-G r4i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG GISS-E2-1-G r5i1p1f2 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG HadGEM3-GC31-LL r5i1p1f3 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG MRI-ESM2-0 r2i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-GHG MRI-ESM2-0 r4i1p1f1 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Warning: only older version exist in the cloud for  hist-GHG NorESM2-LM r1i1p1f1
# Missing data: hist-GHG NorESM2-LM r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-GHG NorESM2-LM r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat ACCESS-CM2 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat ACCESS-CM2 r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat ACCESS-CM2 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat ACCESS-ESM1-5 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat ACCESS-ESM1-5 r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat ACCESS-ESM1-5 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r10i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r11i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r11i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r12i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r12i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r13i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r13i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r14i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r14i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r15i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r15i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r16i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r16i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r17i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r17i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r18i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r18i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r19i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r19i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r1i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r20i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r20i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r21i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r21i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r22i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r22i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r23i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r23i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r24i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r24i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r25i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r25i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r2i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r3i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r4i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r5i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r6i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r7i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r8i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat CanESM5 r9i1p2f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat FGOALS-g3 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat FGOALS-g3 r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat FGOALS-g3 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GFDL-CM4 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GFDL-CM4 r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GFDL-CM4 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r10i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r1i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r1i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r1i1p1f4 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r2i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r2i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r2i1p1f4 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r3i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r3i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r3i1p1f4 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r4i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r4i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r4i1p1f4 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r5i1p1f2 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r5i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r5i1p1f4 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r6i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r7i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r8i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat GISS-E2-1-G r9i1p1f3 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat HadGEM3-GC31-LL r10i1p1f3 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-nat HadGEM3-GC31-LL r5i1p1f3 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-nat HadGEM3-GC31-LL r6i1p1f3 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-nat HadGEM3-GC31-LL r7i1p1f3 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-nat HadGEM3-GC31-LL r8i1p1f3 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-nat HadGEM3-GC31-LL r9i1p1f3 is missing the variables {'rsdt', 'tas', 'rlut', 'rsut'}
# Missing data: hist-nat MIROC6 r10i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r11i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r12i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r13i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r14i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r15i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r16i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r17i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r18i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r19i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r20i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r21i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r22i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r23i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r24i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r25i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r26i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r27i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r28i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r29i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r30i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r31i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r32i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r33i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r34i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r35i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r36i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r37i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r38i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r39i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r40i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r41i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r42i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r43i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r44i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r45i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r46i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r47i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r48i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r49i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r4i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r50i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r5i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r6i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r7i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r8i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MIROC6 r9i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MRI-ESM2-0 r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat MRI-ESM2-0 r4i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat NorESM2-LM r1i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat NorESM2-LM r2i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
# Missing data: hist-nat NorESM2-LM r3i1p1f1 is missing the variables {'rsut', 'rlut', 'rsdt'}
